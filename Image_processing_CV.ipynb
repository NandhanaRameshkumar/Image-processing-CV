# %% [markdown]
# <a href="https://colab.research.google.com/github/NandhanaRameshkumar/Image-processing-CV/blob/main/Image_processing_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread('Cub twin.jpg')
plt.imshow(img)

# %%
cv2.imwrite('Cub twin.jpg',cv2.Canny(img,200,300))
# Out:
# True

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, cmap = 'gray')

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 20))
for i in range(0, 3):
    ax = axs[i]
    ax.imshow(img_rgb[:, :, i], cmap = 'gray')
plt.show()

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
# Plot the converted images
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 20))
ax1.imshow(img_hsv)
ax2.imshow(img_hls)
plt.show()

# %%
img_c = img.copy()
# Draw a rectangle
cv2.rectangle(img_c, pt1 = (500,100), pt2 = (200, 80),
              color = (1000, 1000, 0), thickness =100)
plt.imshow(img_c)

# %%
cv2.circle(img_c, center = (50, 50), radius = 50,
           color = (0, 0, 255), thickness = 5)
plt.imshow(img_c)

# %%
cv2.putText(img_c, text = "They are brothers ",
            org = (0, 150),
            fontFace = cv2.FONT_HERSHEY_DUPLEX,
            fontScale = 2,
            color = (0, 255, 0),
            thickness = 2,
            lineType = cv2.LINE_AA)
plt.imshow(img_c)

# %%
from PIL import Image

img = Image.open("Cub twin.jpg")

img.show()

# %%
from PIL import Image, ImageFilter

# Open an image file
with Image.open('Cub twin.jpg') as img:
    # Apply a filter (e.g., blur)
    blurred_img = img.filter(ImageFilter.BLUR)

    # Save the processed image
    blurred_img.save('output.jpg')

    # Optionally, show the image
    blurred_img.show()

# %%
# Resize image
resized_img = img.resize((800, 600))
resized_img.save('resized.jpg')
resized_img.show()

# %%
# Crop image
cropped_img = img.crop((100, 100, 400, 400))
cropped_img.save('cropped.jpg')
cropped_img.show()

# %%
# Convert to grayscale
grayscale_img = img.convert('L')
grayscale_img.save('grayscale.jpg')
grayscale_img.show()
